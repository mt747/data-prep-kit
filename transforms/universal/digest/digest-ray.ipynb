# %%
# %%capture
# %pip install "data-prep-toolkit[ray]>=0.2.3"
# %pip install pandas

# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_digest.ray.runtime import Digest
from data_processing.utils import GB

# %% [markdown]
# ##### ***** Setup runtime parameters for this transform and invoke the transform

# %%
# %%capture
Digest(input_folder= "test-data/input",
        output_folder= "test-data/output",
        run_locally= True,
        num_cpus= 1,
        memory= 2 * GB,
        runtime_num_workers = 2,
        digest_algorithm= "sha256").transform()

# %%
import pyarrow.parquet as pq
import pandas as pd
pq.read_table('test-data/output/test1.parquet').to_pandas()[['document_id','contents','digest']]
# Out:
#                                           document_id  \
# 0   600fb9cb986bebc4344dbdaba34a2a212d2cd0d51ecb03...
# 1   6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2   10699f104b8aafb34b542e9c28b9c5b4f22f585fbf22e9...
# 3   292293706e6df4757a4b3ddba7fffa4173aedb161acb56...
# 4   a796bd66e5fc1dd55abb1cf92115cbef6086ea6ad0c21c...
# 5   e34c9152459fe1c55a1f6bde873463739daef0924a8588...
# 6   620c2496ae6d48ac61d4457921c56816c0605c1ad041de...
# 7   424462748fbd7f641237d60c2a7e4e68ab7f69e78dbf76...
# 8   33b240f4ce154d4a321f0826c92a20294ac1cb844e99c4...
# 9   6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 10  f6f5ac281bee0775c514256bafa10bbdc2feb43e5a37ef...
# 11  879e30e151e0dd5e14fe28388ea2ff11c14689c94bcefa...
# 12  fa0d8a17d198b8c8b37c1d58fbb3a80d7db91ec255aeeb...
# 13  10376eca1e378b771989536b4b345dca2ff35ee3753b3b...
# 14  c0848aa36ff34140621161a2d83637d9efc4a98324e838...
# 15  6b81311fec7662e1a982a2bb412cd5c3cc00dc61f8988f...
# ...
